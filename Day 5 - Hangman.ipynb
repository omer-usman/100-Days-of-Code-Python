wizard
woozy
wristwatch
wyvern
xylophone
yachtsman
yippee
yoked
youthful
yummy
zephyr
zigzag
zigzagging
zilch
zipper
zodiac
zombie'''
print(''' _                                             
| |                                            
| |__   __ _ _ __   __ _ _ __ ___   __ _ _ __  
| '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \ 
| | | | (_| | | | | (_| | | | | | | (_| | | | |
|_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
                    __/ |                      
                   |___/                       ''')

guessWord=random.choice(words)
a=0
print("Welcome to HANGMAN GAME")
length=len(guessWord)
w=[]
w[:]=("_"*length)
print(w)
while(lives>0):
    flag = 0
    j = 0
    usrInput = input('Please enter a character:')[0]
    print(f'Your single character input was: {usrInput}')
    for i in guessWord:
        if(i==usrInput):
            w[j]=usrInput[0]
            flag=1
        j+=1
    print(w)
    if flag==1:
        flag==0
    else:
        print(HANGMANPICS[a])
        a+=1
        lives-=1
        print(f'Lives you have left:{lives}')
print(f'Word is {guessWord}')
# Out:
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Welcome to HANGMAN GAME
# ['_', '_', '_', '_']
# Please enter a character:a
# Your single character input was: a
# ['_', 'a', '_', '_']
# Please enter a character:m
# Your single character input was: m
# ['_', 'a', '_', '_']
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# Lives you have left:6
# Please enter a character:b
# Your single character input was: b
# ['_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# Lives you have left:5
# Please enter a character:l
# Your single character input was: l
# ['_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# Lives you have left:4
# Please enter a character:e
# Your single character input was: e
# ['_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# Lives you have left:3
# Please enter a character:t
# Your single character input was: t
# ['_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
# Lives you have left:2
# Please enter a character:z
# Your single character input was: z
# ['_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
# Lives you have left:1
# Please enter a character:p
# Your single character input was: p
# ['_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
# Lives you have left:0
# Word is waxy
